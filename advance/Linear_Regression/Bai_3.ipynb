# %% [markdown]
# # Bai 3

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from ucimlrepo import fetch_ucirepo

# %% [markdown]
# ## Data
#
# Details: The real estate valuation is a regression problem. The market historical data set of real estate valuation are collected from Sindian Dist., New Taipei City, Taiwan.
#
# - The inputs are as follows
#   1. X1=the transaction date (for example, 2013.250=2013 March, 2013.500=2013 June, etc.)
#   2. X2=the house age (unit: year)
#   3. X3=the distance to the nearest MRT station (unit: meter)
#   4. X4=the number of convenience stores in the living circle on foot (integer)
#   5. X5=the geographic coordinate, latitude. (unit: degree)
#   6. X6=the geographic coordinate, longitude. (unit: degree)
#
# - The output is as follow:
#   - Y= house price of unit area (10000 New Taiwan Dollar/Ping, where Ping is a local unit, 1 Ping = 3.3 meter squared)

# %%
real_estate_valuation = fetch_ucirepo(id=477)
dataset = real_estate_valuation.data.original
dataset.head()
# Out:
#    No  X1 transaction date  X2 house age  \
# 0   1             2012.917          32.0
# 1   2             2012.917          19.5
# 2   3             2013.583          13.3
# 3   4             2013.500          13.3
# 4   5             2012.833           5.0
#
#    X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                84.87882                               10
# 1                               306.59470                                9
# 2                               561.98450                                5
# 3                               561.98450                                5
# 4                               390.56840                                5
#
#    X5 latitude  X6 longitude  Y house price of unit area
# 0     24.98298     121.54024                        37.9
# 1     24.98034     121.53951                        42.2
# 2     24.98746     121.54391                        47.3
# ...

# %% [markdown]
# ## Tien xu ly
#
# - The dataset has a "No" column, which is an ID, and ID doesn't matter so that I will drop that column.
# - With column X1, we can use translation to avoid scale imbalance and prevent affecting the model.
