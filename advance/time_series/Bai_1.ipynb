# %%
from datetime import date
import pandas as pd

# %%
today = date.today()
today
# Out:
# datetime.date(2026, 1, 23)

# %%
df = pd.DataFrame({
    "year": [2021, 2022],
    "month": [3, 4],
    "day": [24, 25]
})

ts1 = pd.to_datetime(df)
ts2 = pd.to_datetime("24032025", format="%d%m%Y")
ts2
# Out:
# Timestamp('2025-03-24 00:00:00')
